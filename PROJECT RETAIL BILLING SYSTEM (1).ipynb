# %%
import tkinter 
from tkinter import *
from tkinter import messagebox
import random,os,tempfile,smtplib
billnumber=random.randint(100,1000)

def search_bill():
   for i in os.listdir('bills/'):
       if i.split('.')[0] == billEntry.get():
           f=open(f'bills/{i}','r')
           textarea.delete('1.0',END)
           for data in f:
               textarea.insert(END,data)
           f.close()
           break
   else:
       messagebox.showerror('Error','Invalid Bill Number')
    

def clear():
    soapentery.delete(0,END)
    creamentery.delete(0,END)
    facewashentery.delete(0,END)
    hairsprayentery.delete(0,END)
    hairgelentery.delete(0,END)
    bodylotionentery.delete(0,END)
    riceentery.delete(0,END)
    oilentery.delete(0,END)
    daalentery.delete(0,END)
    wheatentery.delete(0,END)
    sugarentery.delete(0,END)
    teaentery.delete(0,END)
    maazaentery.delete(0,END)
    pepsientery.delete(0,END)
    spriteentery.delete(0,END)
    dewentery.delete(0,END)
    frootientery.delete(0,END)
    cockentery.delete(0,END)
    cosmetictaxentery.delete(0,END)
    grocerytaxentery.delete(0,END)
    drinktaxentery.delete(0,END)
    cosmeticpriceentery.delete(0,END)
    grocerypriceentery.delete(0,END)
    drinkpriceentery.delete(0,END)
    nameEntry.delete(0,END)
    phoneEntry.delete(0,END)
    billEntry.delete(0,END)
    textarea.delete(1.0,END)
    



def print_bill():
    if textarea.get(1.0,END)=='\n':
        messagebox.showerror('Error','Bill is empty')
    else:
        file=tempfile.mktemp('.txt')
        open(file,'w').write(textarea.get(1.0,END))
        os.startfile(file,'Print')


    
    



def send_email():
    def send_gmail():
        try:
            ob=smtplib.SMTP('smtp.gmail.com',587)
            ob.starttls()
            ob.login(senderEntry.get(),recieverEntry.get())
            message=email_textarea.get(1.0,END)
            ob.sendmail(senderEntry.get(),recieverEntry.get(),message)
            ob.quit()
            messagebox.showinfo('Success','Bill is successfully sent.')
        except:
            messagebox.showerror('Error','Somthing went wreong. Please tyr again')




        
    if textarea.get(1.0,END)=='\n':
        messagebox.showerror('Error','Bill is empty')
    else:
        root1=Toplevel()
        root1.title('Send Gmail')
        root1.config(bg='gray20')
        root1.resizable(0,0)
        senderFrame=LabelFrame(root1,text='SENDER',font=('times new roman',16,'bold'),bd=6,bg='gray20',fg='white')
        senderFrame.grid(row=0,column=0,padx=40,pady=20)
        
        senderLabel=Label(senderFrame,text="Sender's Email",font=('arial',14,'bold'),bd=6,bg='gray20',fg='white')
        senderLabel.grid(row=0,column=0,padx=10,pady=8)
        senderEntry=Entry(senderFrame,font=('arial',14,'bold'),bd=2,width=23,relief=RIDGE)
        senderEntry.grid(row=0,column=1,padx=10,pady=8)

        passwordLabel=Label(senderFrame,text="Password",font=('arial',14,'bold'),bd=6,bg='gray20',fg='white')
        passwordLabel.grid(row=1,column=0,padx=10,pady=8)
        passwordEntry=Entry(senderFrame,font=('arial',14,'bold'),bd=2,width=23,relief=RIDGE,show='*')
        passwordEntry.grid(row=1,column=1,padx=10,pady=8)

        recipientFrame=LabelFrame(root1,text='RECIPIENT',font=('times new roman',16,'bold'),bd=6,bg='gray20',fg='white')
        recipientFrame.grid(row=1,column=0,padx=40,pady=20)
        recieverLabel=Label(recipientFrame,text="Email Address",font=('arial',14,'bold'),bd=6,bg='gray20',fg='white')
        recieverLabel.grid(row=0,column=0,padx=10,pady=8)
        recieverEntry=Entry(recipientFrame,font=('arial',14,'bold'),bd=2,width=23,relief=RIDGE)
        recieverEntry.grid(row=0,column=1,padx=10,pady=8)

        messageLabel=Label(recipientFrame,text="Message",font=('arial',14,'bold'),bd=6,bg='gray20',fg='white')
        messageLabel.grid(row=1,column=0,padx=10,pady=8)

        email_textarea=Text(recipientFrame,font=('arial',14,'bold'),bd=2,relief=SUNKEN,width=42,height=11)
        email_textarea.grid(row=2,column=0,columnspan=2)
        email_textarea.delete(1.0,END)
        email_textarea.insert(END,textarea.get(1.0,END).replace('*','').replace('-','').replace('\t\t\t','\t\t'))

        sendButton=Button(root1,text='SEND',font=('arial',16,'bold'),width=15,command=send_gmail)
        sendButton.grid(row=2,column=0,pady=20)        
        root1.mainloop

#FUNCTIONALITY PART
def total():
    global soapprice,creamprice,facewashprice,hairsprayprice,hairgelprice,bodylotionprice,riceprice,oilprice,daalprice,wheatprice,sugarprice,teaprice,maazaprice,pepsiprice,spriteprice,dewprice,frootiprice,cockprice,totalbill
    
    #cosmetic price calculation
    soapprice=int(soapentery.get())*20
    creamprice=int(creamentery.get())*50
    facewashprice=int(facewashentery.get())*100
    hairsprayprice=int(hairsprayentery.get())*150
    hairgelprice=int(hairgelentery.get())*120
    bodylotionprice=int(bodylotionentery.get())*180
    totalcosmeticprice=soapprice+creamprice+facewashprice+hairsprayprice+hairgelprice+bodylotionprice
    cosmeticpriceentery.delete(0,END)
    cosmeticpriceentery.insert(0,f'{totalcosmeticprice} Rs')
    cosmetictax=totalcosmeticprice*0.12
    cosmetictaxentery.delete(0,END)
    cosmetictaxentery.insert(0,str(cosmetictax)+'Rs')
    
    #grocery price calculation
    riceprice=int(riceentery.get())*50
    oilprice=int(oilentery.get())*80
    daalprice=int(daalentery.get())*120
    wheatprice=int(wheatentery.get())*80
    sugarprice=int(sugarentery.get())*40
    teaprice=int(teaentery.get())*220
    totalgroceryprice=riceprice+oilprice+daalprice+wheatprice+sugarprice+teaprice
    grocerypriceentery.delete(0,END)
    grocerypriceentery.insert(0,f'{totalgroceryprice} Rs')
    grocerytax=totalgroceryprice*0.05
    grocerytaxentery.delete(0,END)
    grocerytaxentery.insert(0,str(grocerytax)+'Rs')

    #cold drink price calculator
    maazaprice=int(maazaentery.get())*85
    pepsiprice=int(pepsientery.get())*95
    spriteprice=int(spriteentery.get())*85
    dewprice=int(dewentery.get())*80
    frootiprice=int(frootientery.get())*92
    cockprice=int(cockentery.get())*95
    totalcolddrinkprice=maazaprice+pepsiprice+spriteprice+dewprice+frootiprice+cockprice
    drinkpriceentery.delete(0,END)
    drinkpriceentery.insert(0,f'{totalcolddrinkprice} Rs')
    drinktax=totalcolddrinkprice*0.08
    drinktaxentery.delete(0,END)
    drinktaxentery.insert(0,str(drinktax)+'Rs')


    totalbill=totalcosmeticprice+totalgroceryprice+totalcolddrinkprice+cosmetictax+grocerytax+drinktax



def bill_area():
    if nameEntry.get()=='' and phoneEntry.get()=='':
       messagebox.showerror('ERROR','Costumer Detail Are Required')
    elif cosmeticpriceentery.get()=='' and grocerypriceentery.get()=='' and drinkpriceentery.get()=='':
         messagebox.showerror('ERROR','No Products Are Selected')
    elif cosmeticpriceentery.get()=='0 Rs' and grocerypriceentery.get()=='0 Rs' and drinkpriceentery.get()=='0 Rs':
         messagebox.showerror('ERROR','No Products Are Selected')
    else:
         textarea.delete(1.0,END)  

         textarea.insert(END,'\t\t**WELCOME COSTUMER**\n')
         textarea.insert(END, f'\nBill Number: {billnumber}')
         textarea.insert(END, f'\nCostumer Name: {nameEntry.get()}')
         textarea.insert(END, f'\nCostumer Phone Number: {phoneEntry.get()}')
         textarea.insert(END, '\n************************************************************')
         textarea.insert(END, '\nProduct\t\t\tQuantity\t\t\tPrice')
         textarea.insert(END, '\n************************************************************')
         if soapentery.get()!='0':
             textarea.insert(END,f'\nBath Soap\t\t\t{soapentery.get()}\t\t\t{soapprice} Rs')
         if creamentery.get()!='0':
             textarea.insert(END,f'\nCream\t\t\t{creamentery.get()}\t\t\t{creamprice} Rs')
         if facewashentery.get()!='0':
             textarea.insert(END,f'\nFace Wash\t\t\t{facewashentery.get()}\t\t\t{facewashprice} Rs')
         if hairsprayentery.get()!='0':
             textarea.insert(END,f'\nHair Spray\t\t\t{hairsprayentery.get()}\t\t\t{hairsprayprice} Rs')
         if hairgelentery.get()!='0':
             textarea.insert(END,f'\nHair Gel\t\t\t{hairgelentery.get()}\t\t\t{hairgelprice} Rs')
         if bodylotionentery.get()!='0':
             textarea.insert(END,f'\nBody Lotion\t\t\t{bodylotionentery.get()}\t\t\t{bodylotionprice} Rs')
         if riceentery.get()!='0':
             textarea.insert(END,f'\nRice\t\t\t{riceentery.get()}\t\t\t{riceprice} Rs')
         if oilentery.get()!='0':
             textarea.insert(END,f'\nOil\t\t\t{oilentery.get()}\t\t\t{oilprice} Rs')
         if daalentery.get()!='0':
             textarea.insert(END,f'\nDaal\t\t\t{daalentery.get()}\t\t\t{daalprice} Rs')
         if wheatentery.get()!='0':
             textarea.insert(END,f'\nWheat\t\t\t{wheatentery.get()}\t\t\t{wheatprice} Rs')
         if sugarentery.get()!='0':
             textarea.insert(END,f'\nSugar\t\t\t{sugarentery.get()}\t\t\t{sugarprice} Rs')
         if teaentery.get()!='0':
             textarea.insert(END,f'\nTea\t\t\t{teaentery.get()}\t\t\t{teaprice} Rs')
         if dewentery.get()!='0':
             textarea.insert(END,f'\nDew\t\t\t{dewentery.get()}\t\t\t{dewprice} Rs')
         if pepsientery.get()!='0':
             textarea.insert(END,f'\nPepsi\t\t\t{pepsientery.get()}\t\t\t{pepsiprice} Rs')
         if maazaentery.get()!='0':
             textarea.insert(END,f'\nMaaza\t\t\t{maazaentery.get()}\t\t\t{maazaprice} Rs')
         if spriteentery.get()!='0':
             textarea.insert(END,f'\nSprite\t\t\t{spriteentery.get()}\t\t\t{spriteprice} Rs')      
         if frootientery.get()!='0':
             textarea.insert(END,f'\nFrooti\t\t\t{frootientery.get()}\t\t\t{frootiprice} Rs')
         if cockentery.get()!='0':
             textarea.insert(END,f'\nCock\t\t\t{cockentery.get()}\t\t\t{cockprice} Rs')
         textarea.insert(END, '\n------------------------------------------------------------')

         if cosmetictaxentery.get()!='0.0 Rs':
             textarea.insert(END,f'\nCosmetic Tax\t\t{cosmetictaxentery.get()}')
         if grocerytaxentery.get()!='0.0 Rs':
             textarea.insert(END,f'\nGrocery Tax\t\t{grocerytaxentery.get()}')
         if drinktaxentery.get()!='0.0 Rs':
             textarea.insert(END,f'\nCold Drink Tax\t\t{drinktaxentery.get()}')
        
         textarea.insert(END,f'\n\nTotal Bill \t\t\t\t {totalbill}')
         textarea.insert(END, '\n------------------------------------------------------------')
         save_bill()



if not os.path.exists('bills'):
    os.mkdir('bills')


def save_bill():
    global billnumber
    result=messagebox.askyesno('Confirm','Do you want to save the bil? ')
    if result:
        bill_content=textarea.get(1.0,END)
        file=open(f'bills/ {billnumber}.txt','w')
        file.write(bill_content)
        file.close()
        messagebox.showinfo('Success',f' bill number{billnumber} is saved successfully')
        billnumber=random.randint(100,1000)








#GUI PART
root=Tk()
root.title('REATIL BILLING SYSTEM')
root.geometry('1270x685')

headingLabel=Label(root,text='RETAIL BILLING SYSTEM',font=('times new roman',30,'bold'),bg='gray20',fg='gold',bd=12,relief=GROOVE)
headingLabel.pack(fill=X,)

costumer_detail_frame=LabelFrame(root,text='COSTUMER DETAILS',font=('times new roman',15,'bold'),bg='gray20',fg='gold',bd=8,relief=GROOVE)
costumer_detail_frame.pack(fill=X,pady=2)

nameLabel=Label(costumer_detail_frame,text='NAME',font=('times new roman',15,'bold'),bg='gray20',fg='white')
nameLabel.grid(row=0,column=0,padx=20,pady=2)
nameEntry=Entry(costumer_detail_frame,font=('arial',15),bd=7,width=18)
nameEntry.grid(row=0,column=1,padx=10)

phoneLabel=Label(costumer_detail_frame,text='PHONE NUMBER',font=('times new roman',15,'bold'),bg='gray20',fg='white')
phoneLabel.grid(row=0,column=2,padx=20,pady=2)
phoneEntry=Entry(costumer_detail_frame,font=('arial',15),bd=7,width=18)
phoneEntry.grid(row=0,column=3,padx=10)

billnoLabel=Label(costumer_detail_frame,text='BILL NO',font=('times new roman',15,'bold'),bg='gray20',fg='white')
billnoLabel.grid(row=0,column=4,padx=20,pady=2)
billEntry=Entry(costumer_detail_frame,font=('arial',15),bd=7,width=18)
billEntry.grid(row=0,column=5,padx=10)

searchbutton=Button(costumer_detail_frame,text='SEARCH',font=('arial',12,'bold'),bd=7,command=search_bill)
searchbutton.grid(row=0,column=6,padx=20,pady=8)

productframe=Frame(root)
productframe.pack(fill=X)

cosmeticframe=LabelFrame(productframe,text='COSMETICS',font=('times new roman',15,'bold'),fg='gold',bd=8,relief=GROOVE,bg='gray20')
cosmeticframe.grid(row=0,column=0)

bathsoaplabel=Label(cosmeticframe,text='BATH SOAP',font=('times new roman',15,'bold'),bg='gray20',fg='white')
bathsoaplabel.grid(row=0,column=0,pady=5,padx=5)
soapentery=Entry(cosmeticframe,font=('times new roman',15,'bold'),width=10,bd=5)
soapentery.grid(row=0,column=1,pady=5,padx=5)
soapentery.insert(0,0)
creamlabel=Label(cosmeticframe,text='FACE CREAM',font=('times new roman',15,'bold'),bg='gray20',fg='white')
creamlabel.grid(row=1,column=0,pady=5,padx=5)
creamentery=Entry(cosmeticframe,font=('times new roman',15,'bold'),width=10,bd=5)
creamentery.grid(row=1,column=1,pady=5,padx=5)
creamentery.insert(0,0)
facewashlabel=Label(cosmeticframe,text='FACE WASH',font=('times new roman',15,'bold'),bg='gray20',fg='white')
facewashlabel.grid(row=2,column=0,pady=5,padx=5)
facewashentery=Entry(cosmeticframe,font=('times new roman',15,'bold'),width=10,bd=5)
facewashentery.grid(row=2,column=1,pady=5,padx=5)
facewashentery.insert(0,0)
hairspraylabel=Label(cosmeticframe,text='HAIR SPRAY',font=('times new roman',15,'bold'),bg='gray20',fg='white')
hairspraylabel.grid(row=3,column=0,pady=5,padx=5)
hairsprayentery=Entry(cosmeticframe,font=('times new roman',15,'bold'),width=10,bd=5)
hairsprayentery.grid(row=3,column=1,pady=5,padx=5)
hairsprayentery.insert(0,0)
hairgellabel=Label(cosmeticframe,text='HAIR GEL',font=('times new roman',15,'bold'),bg='gray20',fg='white')
hairgellabel.grid(row=4,column=0,pady=5,padx=5)
hairgelentery=Entry(cosmeticframe,font=('times new roman',15,'bold'),width=10,bd=5)
hairgelentery.grid(row=4,column=1,pady=5,padx=5)
hairgelentery.insert(0,0)
bodylotionlabel=Label(cosmeticframe,text='BODY LOTION',font=('times new roman',15,'bold'),bg='gray20',fg='white')
bodylotionlabel.grid(row=5,column=0,pady=5,padx=5)
bodylotionentery=Entry(cosmeticframe,font=('times new roman',15,'bold'),width=10,bd=5)
bodylotionentery.grid(row=5,column=1,pady=5,padx=5)
bodylotionentery.insert(0,0)


groceryframe=LabelFrame(productframe,text='GROCERY',font=('times new roman',15,'bold'),fg='gold',bd=8,relief=GROOVE,bg='gray20')
groceryframe.grid(row=0,column=1)

ricelabel=Label(groceryframe,text='RICE',font=('times new roman',15,'bold'),bg='gray20',fg='white')
ricelabel.grid(row=0,column=0,pady=5,padx=5)
riceentery=Entry(groceryframe,font=('times new roman',15,'bold'),width=10,bd=5)
riceentery.grid(row=0,column=1,pady=5,padx=5)
riceentery.insert(0,0)
oillabel=Label(groceryframe,text='OIL',font=('times new roman',15,'bold'),bg='gray20',fg='white')
oillabel.grid(row=1,column=0,pady=5,padx=5)
oilentery=Entry(groceryframe,font=('times new roman',15,'bold'),width=10,bd=5)
oilentery.grid(row=1,column=1,pady=5,padx=5)
oilentery.insert(0,0)
daallabel=Label(groceryframe,text='DAAL',font=('times new roman',15,'bold'),bg='gray20',fg='white')
daallabel.grid(row=2,column=0,pady=5,padx=5)
daalentery=Entry(groceryframe,font=('times new roman',15,'bold'),width=10,bd=5)
daalentery.grid(row=2,column=1,pady=5,padx=5)
daalentery.insert(0,0)
wheatlabel=Label(groceryframe,text='WHEAT',font=('times new roman',15,'bold'),bg='gray20',fg='white')
wheatlabel.grid(row=3,column=0,pady=5,padx=5)
wheatentery=Entry(groceryframe,font=('times new roman',15,'bold'),width=10,bd=5)
wheatentery.grid(row=3,column=1,pady=5,padx=5)
wheatentery.insert(0,0)
sugarlabel=Label(groceryframe,text='SUGAR',font=('times new roman',15,'bold'),bg='gray20',fg='white')
sugarlabel.grid(row=4,column=0,pady=5,padx=5)
sugarentery=Entry(groceryframe,font=('times new roman',15,'bold'),width=10,bd=5)
sugarentery.grid(row=4,column=1,pady=5,padx=5)
sugarentery.insert(0,0)
tealabel=Label(groceryframe,text='TEA',font=('times new roman',15,'bold'),bg='gray20',fg='white')
tealabel.grid(row=5,column=0,pady=5,padx=5)
teaentery=Entry(groceryframe,font=('times new roman',15,'bold'),width=10,bd=5)
teaentery.grid(row=5,column=1,pady=5,padx=5)
teaentery.insert(0,0)


colddrinkframe=LabelFrame(productframe,text='COLD DRINK',font=('times new roman',15,'bold'),fg='gold',bd=8,relief=GROOVE,bg='gray20')
colddrinkframe.grid(row=0,column=2)

maazalabel=Label(colddrinkframe,text='MAAZA',font=('times new roman',15,'bold'),bg='gray20',fg='white')
maazalabel.grid(row=0,column=0,pady=5,padx=5)
maazaentery=Entry(colddrinkframe,font=('times new roman',15,'bold'),width=10,bd=5)
maazaentery.grid(row=0,column=1,pady=5,padx=5)
maazaentery.insert(0,0)
pepsilabel=Label(colddrinkframe,text='PEPSI',font=('times new roman',15,'bold'),bg='gray20',fg='white')
pepsilabel.grid(row=1,column=0,pady=5,padx=5)
pepsientery=Entry(colddrinkframe,font=('times new roman',15,'bold'),width=10,bd=5)
pepsientery.grid(row=1,column=1,pady=5,padx=5)
pepsientery.insert(0,0)
spritelabel=Label(colddrinkframe,text='SPRITE',font=('times new roman',15,'bold'),bg='gray20',fg='white')
spritelabel.grid(row=2,column=0,pady=5,padx=5)
spriteentery=Entry(colddrinkframe,font=('times new roman',15,'bold'),width=10,bd=5)
spriteentery.grid(row=2,column=1,pady=5,padx=5)
spriteentery.insert(0,0)
dewlabel=Label(colddrinkframe,text='DEW',font=('times new roman',15,'bold'),bg='gray20',fg='white')
dewlabel.grid(row=3,column=0,pady=5,padx=5)
dewentery=Entry(colddrinkframe,font=('times new roman',15,'bold'),width=10,bd=5)
dewentery.grid(row=3,column=1,pady=5,padx=5)
dewentery.insert(0,0)
frootilabel=Label(colddrinkframe,text='FROOTI',font=('times new roman',15,'bold'),bg='gray20',fg='white')
frootilabel.grid(row=4,column=0,pady=5,padx=5)
frootientery=Entry(colddrinkframe,font=('times new roman',15,'bold'),width=10,bd=5)
frootientery.grid(row=4,column=1,pady=5,padx=5)
frootientery.insert(0,0)
cocklabel=Label(colddrinkframe,text='COCA COLA',font=('times new roman',15,'bold'),bg='gray20',fg='white')
cocklabel.grid(row=5,column=0,pady=5,padx=5)
cockentery=Entry(colddrinkframe,font=('times new roman',15,'bold'),width=10,bd=5)
cockentery.grid(row=5,column=1,pady=5,padx=5)
cockentery.insert(0,0)



billframe=Frame(productframe,bd=8,relief=GROOVE)
billframe.grid(row=0,column=3,padx=10)

billarealabel=Label(billframe,text='BILL AREA',font=('times new roman',15,'bold'),bd=7,relief=GROOVE)
billarealabel.pack(fill=X)
scrollbar=Scrollbar(billframe,orient=VERTICAL)
scrollbar.pack(side=RIGHT,fill=Y)
textarea=Text(billframe,height=15,width=60,yscrollcommand=scrollbar.set)
textarea.pack()
scrollbar.config(command=textarea.yview)

billmenuframe=LabelFrame(root,text='BILL MENU',font=('times new roman',15,'bold'),fg='gold',bd=8,relief=GROOVE,bg='gray20')
billmenuframe.pack(fill=X)

cosmeticpricelabel=Label(billmenuframe,text='COSMETIC PRICE',font=('times new roman',15,'bold'),bg='gray20',fg='white')
cosmeticpricelabel.grid(row=0,column=0,pady=9,padx=10)
cosmeticpriceentery=Entry(billmenuframe,font=('times new roman',15,'bold'),width=10,bd=5)
cosmeticpriceentery.grid(row=0,column=1,pady=9,padx=10)
grocerypricelabel=Label(billmenuframe,text='GROCERY PRICE',font=('times new roman',15,'bold'),bg='gray20',fg='white')
grocerypricelabel.grid(row=1,column=0,pady=9,padx=10)
grocerypriceentery=Entry(billmenuframe,font=('times new roman',15,'bold'),width=10,bd=5)
grocerypriceentery.grid(row=1,column=1,pady=9,padx=10)
drinkpricelabel=Label(billmenuframe,text='COLD DRINK PRICE',font=('times new roman',15,'bold'),bg='gray20',fg='white')
drinkpricelabel.grid(row=2,column=0,pady=9,padx=10)
drinkpriceentery=Entry(billmenuframe,font=('times new roman',15,'bold'),width=10,bd=5)
drinkpriceentery.grid(row=2,column=1,pady=9,padx=10)

cosmetictaxlabel=Label(billmenuframe,text='COSMETIC TAX',font=('times new roman',15,'bold'),bg='gray20',fg='white')
cosmetictaxlabel.grid(row=0,column=2,pady=9,padx=10)
cosmetictaxentery=Entry(billmenuframe,font=('times new roman',15,'bold'),width=10,bd=5)
cosmetictaxentery.grid(row=0,column=3,pady=9,padx=10)
grocerytaxlabel=Label(billmenuframe,text='GROCERY TAX',font=('times new roman',15,'bold'),bg='gray20',fg='white')
grocerytaxlabel.grid(row=1,column=2,pady=9,padx=10)
grocerytaxentery=Entry(billmenuframe,font=('times new roman',15,'bold'),width=10,bd=5)
grocerytaxentery.grid(row=1,column=3,pady=9,padx=10)
drinktaxlabel=Label(billmenuframe,text='COLD DRINK TAX',font=('times new roman',15,'bold'),bg='gray20',fg='white')
drinktaxlabel.grid(row=2,column=2,pady=9,padx=10)
drinktaxentery=Entry(billmenuframe,font=('times new roman',15,'bold'),width=10,bd=5)
drinktaxentery.grid(row=2,column=3,pady=9,padx=10)

buttonframe=Frame(billmenuframe,bd=8,relief=GROOVE)
buttonframe.grid(row=0,column=4,rowspan=3)

total=Button(buttonframe,text='TOTAL',font=('arial',16,'bold'),bg='gray20',fg='white',bd=5,width=8,pady=5,command=total)
total.grid(row=0,column=0)
bill=Button(buttonframe,text='BILL',font=('arial',16,'bold'),bg='gray20',fg='white',bd=5,width=8,pady=5,command=bill_area)
bill.grid(row=0,column=1)
printb=Button(buttonframe,text='PRINT',font=('arial',16,'bold'),bg='gray20',fg='white',bd=5,width=8,pady=5,command=print_bill)
printb.grid(row=0,column=2)
mail=Button(buttonframe,text='EMAIL',font=('arial',16,'bold'),bg='gray20',fg='white',bd=5,width=8,pady=5,command=send_email)
mail.grid(row=0,column=3)
clear=Button(buttonframe,text='CLEAR',font=('arial',16,'bold'),bg='gray20',fg='white',bd=5,width=8,pady=5,command=clear)
clear.grid(row=0,column=4)

root.mainloop()

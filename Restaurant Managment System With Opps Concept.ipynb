# %%
class TheProtienClub:    
    def __init__(self):
        print('\t\t\t\t PLEASE WELCOME TO THE PROTIEN CLUB')      
        print('\t\t\t\t\t VEG AND NON VEG')                        
        print('\t\t\t\t BEST PLACE FOR YOUR COMPLETE FAMILY')
        print('\n\t\t\t\t\t\t  MENU')
        menu= ['INDIAN','CHINIES','NON VEG','KOREAN']
        for items in menu:
            print('\n\t\t\t\t\t\t',items)

    def indianfood(self):       
        l=['NORTH INDIAN','SOUTH INDIAN','BENGALI','RAJASHTANI']
        for k in l:
            print(k)

    def north_indian(self):        
        m=['DAAL BATI CHURMA','RAJMA CHAWAL','KADHI CHAWAL','SHAHI PANEER','KADHAI PANEER','MALAI KOFTA']
        p=[120,100,100,150,160,140]
        northindian_={'NORTH INDIA FOOD':m,'PRICE':p}
        import pandas as pd
        df=pd.DataFrame(northindian_)
        print('\n\n NORTH INDIAN FOOD TYPE \n\n')
        print(df)
        d=[]
        while m:
            m=True
            pos=int(input('PLEASE CHOSSE POSIOTION OF FOOD :'))
            qty=int(input('PLEASE ENTER HOW MUCH QUANTITY YOU WANT :'))
            z=northindian_['PRICE'][pos]
            y=z*qty
            d.append(y)
            q=input('DO YOU WANT TO OREDER ANYTHING ELSE : YES/NO ')
            if q=='no':
                break
        t=sum(d)
        m=t*0.05
        k=t+m
        print('YOU HAVE TO PAY 5% EXTRA AS SERVICE TAX.... THANK YOU')
        print('TOTOAL AMOUNT WITHOUT SERVICE TAX',t,'RUPEES')
        print('TOTAL AMOUNT WITH SERVICE TAX',k,'RUPEES')
        print('THNKS FOR VISITING THE PROTIEN CLUB....')

    def south_indian(self):
        m=['IDLI','DOSA','VADA','RAWA','APPAM','PUTTU']
        p=[100,120,50,100,120,150]
        southindian_={'SOUTH INDIAN FOOD':m,'PRICE':p}
        import pandas as pd
        df=pd.DataFrame(southindian_)
        print('\n\n SOUTH INDIAN FOOD TYPE \n\n')
        print(df)
        d=[]
        while m:
            m=True
            pos=int(input('PLEASE CHOOSE POSITION OF FOOD'))
            qty=int(input('PLEASE ENTER HOW MUCH QUANTITY YOU WANT'))
            z=southindian_['PRICE'][pos]
            y=z*qty
            d.append(y)
            q=input('DO YOU WANT TO ORDER ANYTHING ELSE : YES/NO ')
            if q=='no':
                break
        t=sum(d)
        m=t*0.05
        k=t+m
        print('YOU HAVE TO PAY 5% EXTRA AS SERVICE TAX.... THANK YOU')
        print('TOTOAL AMOUNT WITHOUT SERVICE TAX',t,'RUPEES')
        print('TOTAL AMOUNT WITH SERVICE TAX',k,'RUPEES')
        print('THNKS FOR VISITING THE PROTIEN CLUB....')

    def bengali(self):
        m=['MISTI DOHI','ILLISH MASH','SANDESH','KOLAR BORA','BHETKI MACHER PATURI']
        p=[150,120,180,150,160]
        bengali_={'BENGALI FOOD':m,'PRICE':p}
        import pandas as pd
        df=pd.DataFrame(bengali_)
        print('\n\n BENGALI FOOD \n\n')
        print(df)
        d=[]
        while m:
            m=True
            pos=int(input('PLEASE CHOSE POSITION OF FOOD'))
            qty=int(input('PLEASE ENTER HOW MUCH QUANTITY YOU WANT'))
            z=bengali_['PRICE'][pos]
            y=z*qty
            d.append(y)
            q=input('DO YOU WANT TO ORDER ANYTHING ELSE : YES/NO ')
            if q=='no':
                break
        t=sum(d)
        m=t*0.05
        k=t+m
        print('YOU HAVE TO PAY 5% EXTRA AS SERVICE TAX.... THANK YOU')
        print('TOTOAL AMOUNT WITHOUT SERVICE TAX',t,'RUPEES')
        print('TOTAL AMOUNT WITH SERVICE TAX',k,'RUPEES')
        print('THNKS FOR VISITING THE PROTIEN CLUB....')

    def rajasthani(self):
        m=['DAAL BATI CHURMA','GHEWAR','LAAL MAANS','GATTE KI SABJI','BAJRA KI RAB']
        p=[120,400,250,120,150]
        rajasthani_={'RAJASTHANI FOOD ITMES':m,'PRICE':p}
        import pandas as pd
        df=pd.DataFrame(rajasthani_)
        print('\n\n RAJASTHANI FOOD \n\n')
        print(df)
        d=[]
        while m:
            m=True
            pos=int(input('PLEASE CHOSE THE POSITION OF FOOD '))
            qty=int(input('PLEASE ENTER HOW MUCH QUANTITY YOU WANT'))
            z=rajasthani_['PRICE'][pos]
            y=z*qty
            d.append(y)
            q=input('DO YOU WANT TO ORDER ANYTHING ELSE : YES/NO')
            if q=='no':
                break
        t=sum(d)
        m=t*0.05
        k=t+m
        print('YOU HAVE TO PAY 5% EXTRA AS SERVICE TAX.... THANK YOU')
        print('TOTOAL AMOUNT WITHOUT SERVICE TAX',t,'RUPEES')
        print('TOTAL AMOUNT WITH SERVICE TAX',k,'RUPEES')
        print('THNKS FOR VISITING THE PROTIEN CLUB....')

    
    def chinies(self):
        m=['CHOWMIN','HAKKA NOODLE','CHILLI POTATO','HONEY CHILLI POTATO','MOMOZ','FRENCH FRIES']
        p=[90,130,120,150,80,100]
        chinies_={'CHINIES FOOD':m,'PRICE':p}
        import pandas as pd
        df=pd.DataFrame(chinies_)
        print('\n\n CHINIES FOOD \n\n')
        print(df)
        d=[]
        while m:
            m=True
            pos=int(input('PLEASE CHOSE THE POSITION OF FOOD '))
            qty=int(input('PLEASE ENTER HOW MUCH QUANTITY YOU WANT'))
            z=chinies_['PRICE'][pos]
            y=z*qty
            d.append(y)
            q=input('DO YOU WANT TO ORDER ANYTHING ELSE : YES/NO')
            if q=='no':
                break
        t=sum(d)
        m=t*0.05
        k=t+m
        print('YOU HAVE TO PAY 5% EXTRA AS SERVICE TAX.... THANK YOU')
        print('TOTOAL AMOUNT WITHOUT SERVICE TAX',t,'RUPEES')
        print('TOTAL AMOUNT WITH SERVICE TAX',k,'RUPEES')
        print('THNKS FOR VISITING THE PROTIEN CLUB....')


    def non_veg(self):
        m=['BIRYANI','KORMA','DUM BIRYANI','NAHARI','SHORMA']
        p=[220,120,250,180,150]
        non_veg_={'NON VEG':m,'PRICE':p}
        import pandas as pd
        df=pd.DataFrame(non_veg_)
        print('\n\n NON VEG \n\n')
        print(df)
        d=[]
        while m:
            m=True
            pos=int(input('PLEASE CHOSE THE POSITION OF FOOD '))
            qty=int(input('PLEASE ENTER HOW MUCH QUANTITY YOU WANT'))
            z=non_veg_['PRICE'][pos]
            y=z*qty
            d.append(y)
            q=input('DO YOU WANT TO ORDER ANYTHING ELSE : YES/NO')
            if q=='no':
                break
        t=sum(d)
        m=t*0.05
        k=t+m
        print('YOU HAVE TO PAY 5% EXTRA AS SERVICE TAX.... THANK YOU')
        print('TOTOAL AMOUNT WITHOUT SERVICE TAX',t,'RUPEES')
        print('TOTAL AMOUNT WITH SERVICE TAX',k,'RUPEES')
        print('THNKS FOR VISITING THE PROTIEN CLUB....')


obj=TheProtienClub()
x=input('PLEASE CHOOSE....WHAT FOOD DO YOU WANT TO ORDER')
if x=="indian":
    print(obj.indianfood())
    y=input('PLEASE CHOOSE.... WHICH DISH YOU WANT TO ORDER')
    if y=='northindian':
        print(obj.north_indian())
    if y=='southindian':
        print(obj.south_indian())
    if y=='bengali':
        print(obj.bengali())
    if y=='rajasthani':
        print(obj.rajasthani())
if x=='chinies':
    print(obj.chinies())
if x=='nonveg':
    print(obj.non_veg())
# Out:
# 				 PLEASE WELCOME TO THE PROTIEN CLUB
# 					 VEG AND NON VEG
# 				 BEST PLACE FOR YOUR COMPLETE FAMILY
#
# 						  MENU
#
# 						 INDIAN
#
# 						 CHINIES
#
# 						 NON VEG
#
# 						 KOREAN
# PLEASE CHOOSE....WHAT FOOD DO YOU WANT TO ORDER indian
# NORTH INDIAN
# SOUTH INDIAN
# BENGALI
# RAJASHTANI
# None
# PLEASE CHOOSE.... WHICH DISH YOU WANT TO ORDER northindian
#  NORTH INDIAN FOOD TYPE
#
#
#    NORTH INDIA FOOD  PRICE
# 0  DAAL BATI CHURMA    120
# 1      RAJMA CHAWAL    100
# 2      KADHI CHAWAL    100
# 3      SHAHI PANEER    150
# 4     KADHAI PANEER    160
# 5       MALAI KOFTA    140
# PLEASE CHOSSE POSIOTION OF FOOD : 0
# PLEASE ENTER HOW MUCH QUANTITY YOU WANT : 2
# DO YOU WANT TO OREDER ANYTHING ELSE : YES/NO  no
# YOU HAVE TO PAY 5% EXTRA AS SERVIR TAX.... THANK YOU
# TOTOAL AMOUNT WITHOUT SERVICE TAX 240 RUPEES
# TOTAL AMOUNT WITH SERVICE TAX 252.0 RUPEES
# THNKS FOR VISITING THE PROTIEN CLUB....
# None
